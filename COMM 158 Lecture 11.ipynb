# %%
import seaborn as sns

#Load the "tips" dataset
tipsDf=sns.load_dataset("tips")

#display the first few rows
print(tipsDf.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
record={"name": "Alice", "age": 30, "city":"New York"}
print(record)
# Out:
# {'name': 'Alice', 'age': 30, 'city': 'New York'}

# %%
import pandas as pd
recordSe=pd.Series(record)
print(recordSe)
# Out:
# name       Alice
# age           30
# city    New York
# dtype: object

# %%
recordSe.to_dict()
# Out:
# {'name': 'Alice', 'age': 30, 'city': 'New York'}

# %%
tipsDf.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
tipsDf.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
transposedDf=tipsDf.T
print(transposedDf.head())
# Out:
#                0      1      2      3       4      5     6      7      8    \
# total_bill   16.99  10.34  21.01  23.68   24.59  25.29  8.77  26.88  15.04
# tip           1.01   1.66    3.5   3.31    3.61   4.71   2.0   3.12   1.96
# sex         Female   Male   Male   Male  Female   Male  Male   Male   Male
# smoker          No     No     No     No      No     No    No     No     No
# day            Sun    Sun    Sun    Sun     Sun    Sun   Sun    Sun    Sun
#
#               9    ...    234    235   236    237     238    239     240  \
# total_bill  14.78  ...  15.53  10.07  12.6  32.83   35.83  29.03   27.18
# tip          3.23  ...    3.0   1.25   1.0   1.17    4.67   5.92     2.0
# sex          Male  ...   Male   Male  Male   Male  Female   Male  Female
# smoker         No  ...    Yes     No   Yes    Yes      No     No     Yes
# day           Sun  ...    Sat    Sat   Sat    Sat     Sat    Sat     Sat
#
#               241    242     243
# total_bill  22.67  17.82   18.78
# ...

# %%
tipsDf["smoker"]
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 239     No
# 240    Yes
# 241    Yes
# 242     No
# 243     No
# Name: smoker, Length: 244, dtype: category
# Categories (2, object): ['Yes', 'No']

# %%
tipsDf.smoker
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 239     No
# 240    Yes
# 241    Yes
# 242     No
# 243     No
# Name: smoker, Length: 244, dtype: category
# Categories (2, object): ['Yes', 'No']

# %%
tipsDf.loc[0]
# Out:
# total_bill     16.99
# tip             1.01
# sex           Female
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 0, dtype: object

# %%
tipsCents=tipsDf["tip"]*100
tipsCents
# Out:
# 0      101.0
# 1      166.0
# 2      350.0
# 3      331.0
# 4      361.0
#        ...
# 239    592.0
# 240    200.0
# 241    200.0
# 242    175.0
# 243    300.0
# Name: tip, Length: 244, dtype: float64

# %%
percentage=tipsDf["tip"]/tipsDf["total_bill"]
print(percentage.head())
# Out:
# 0    0.059447
# 1    0.160542
# 2    0.166587
# 3    0.139780
# 4    0.146808
# dtype: float64

# %%
tipsDf["sex"]=="Male"
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 239     True
# 240    False
# 241     True
# 242     True
# 243    False
# Name: sex, Length: 244, dtype: bool

# %%
maleDf=tipsDf[tipsDf["sex"]=="Male"]
print(maleDf.head())
# Out:
#    total_bill   tip   sex smoker  day    time  size
# 1       10.34  1.66  Male     No  Sun  Dinner     3
# 2       21.01  3.50  Male     No  Sun  Dinner     3
# 3       23.68  3.31  Male     No  Sun  Dinner     2
# 5       25.29  4.71  Male     No  Sun  Dinner     4
# 6        8.77  2.00  Male     No  Sun  Dinner     2

# %%
tipsDf[(tipsDf["sex"]=="Female")&(tipsDf["smoker"]=="Yes")]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1
# 72        26.86  3.14  Female    Yes   Sat  Dinner     2
# 73        25.28  5.00  Female    Yes   Sat  Dinner     2
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2
# 100       11.35  2.50  Female    Yes   Fri  Dinner     2
# 101       15.38  3.00  Female    Yes   Fri  Dinner     2
# 102       44.30  2.50  Female    Yes   Sat  Dinner     3
# 103       22.42  3.48  Female    Yes   Sat  Dinner     2
# 109       14.31  4.00  Female    Yes   Sat  Dinner     2
# 164       17.51  3.00  Female    Yes   Sun  Dinner     2
# 168       10.59  1.61  Female    Yes   Sat  Dinner     2
# 169       10.63  2.00  Female    Yes   Sat  Dinner     2
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2
# 186       20.90  3.50  Female    Yes   Sun  Dinner     3
# ...

# %%
maleDf=tipsDf[tipsDf["sex"]=="Male"]
maleDf.head()
# Out:
#    total_bill   tip   sex smoker  day    time  size
# 1       10.34  1.66  Male     No  Sun  Dinner     3
# 2       21.01  3.50  Male     No  Sun  Dinner     3
# 3       23.68  3.31  Male     No  Sun  Dinner     2
# 5       25.29  4.71  Male     No  Sun  Dinner     4
# 6        8.77  2.00  Male     No  Sun  Dinner     2

# %%
femaleDf=tipsDf[tipsDf["sex"]=="Female"]
femaleDf.head()
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 16       10.33  1.67  Female     No  Sun  Dinner     3

# %%
maleMean=maleDf["tip"].mean()
femaleMean=femaleDf["tip"].mean()
print("male mean: ", maleMean)
print("female mean: ", femaleMean)
# Out:
# male mean:  3.0896178343949043
# female mean:  2.8334482758620685

# %%
means=tipsDf.groupby("sex")["tip"].mean()
means
# Out:
# /tmp/ipython-input-1144542339.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   means=tipsDf.groupby("sex")["tip"].mean()
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64
